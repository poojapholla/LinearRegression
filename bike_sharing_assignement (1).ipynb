# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !ls /Users/z004ngl/Desktop
# Out:
# Linear+Regression+Subjective+Questions.docx
# Linear+Regression+Subjective+Questions.pdf
# Movies.csv
# README.md
# Screenshot 2023-02-14 at 11.52.07 AM.png
# Screenshot 2023-02-28 at 10.14.34 PM.png
# Screenshot 2023-02-28 at 10.14.38 PM.png
# Screenshot 2023-02-28 at 10.14.44 PM.png
# Screenshot 2023-03-08 at 11.30.23 AM.png
# Screenshot 2023-04-13 at 9.35.09 AM.png
# Screenshot 2023-05-08 at 12.21.59 PM.png
# Screenshot 2023-05-23 at 2.53.16 PM.png
# Screenshot 2023-05-23 at 2.54.59 PM.png
# Screenshot 2023-05-23 at 6.19.22 PM.png
# Screenshot 2023-05-30 at 11.28.32 AM.png
# Screenshot 2023-08-10 at 9.57.41 AM.png
# Screenshot 2023-08-18 at 10.29.35 AM.png
# Screenshot 2023-09-04 at 1.14.41 PM.png
# Screenshot 2023-09-04 at 12.06.38 PM.png
# Screenshot 2023-09-04 at 12.40.26 PM.png
# advertising.csv
# currencies.csv
# day.csv
# grades.csv
# loan.csv
# popularity.csv

# %%
bike_data = pd.read_csv("/Users/z004ngl/Desktop/day.csv")
bike_data
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  01-01-2018       1   0     1        0        6           0
# 1          2  02-01-2018       1   0     1        0        0           0
# 2          3  03-01-2018       1   0     1        0        1           1
# 3          4  04-01-2018       1   0     1        0        2           1
# 4          5  05-01-2018       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 725      726  27-12-2019       1   1    12        0        4           1
# 726      727  28-12-2019       1   1    12        0        5           1
# 727      728  29-12-2019       1   1    12        0        6           0
# 728      729  30-12-2019       1   1    12        0        0           0
# 729      730  31-12-2019       1   1    12        0        1           1
#
#      weathersit       temp     atemp      hum  windspeed  casual  registered  \
# ...

# %%
bike_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    object
#  2   season      730 non-null    int64
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    int64
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    int64
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.4+ KB

# %%
bike_data.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  01-01-2018       1   0     1        0        6           0
# 1        2  02-01-2018       1   0     1        0        0           0
# 2        3  03-01-2018       1   0     1        0        1           1
# 3        4  04-01-2018       1   0     1        0        2           1
# 4        5  05-01-2018       1   0     1        0        3           1
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350  43.6957  12.522300      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
bike_data.shape
# Out:
# (730, 16)

# %%
bike_data.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean   365.500000    2.498630    0.500000    6.526027    0.028767    2.997260
# std    210.877136    1.110184    0.500343    3.450215    0.167266    2.006161
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.250000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    365.500000    3.000000    0.500000    7.000000    0.000000    3.000000
# 75%    547.750000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    730.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean     0.683562    1.394521   20.319259   23.726322   62.765175   12.763620
# ...

# %%
## Exploratory Data Analysis ##

# %%
## Check for missing values

round(100*bike_data.isnull().sum()/len(bike_data), 2)

# It shows that none of the columns has null values.
# Out:
# instant       0.0
# dteday        0.0
# season        0.0
# yr            0.0
# mnth          0.0
# holiday       0.0
# weekday       0.0
# workingday    0.0
# weathersit    0.0
# temp          0.0
# atemp         0.0
# hum           0.0
# windspeed     0.0
# casual        0.0
# registered    0.0
# cnt           0.0
# dtype: float64

# %%
# Dropping all the duplicates and verifying its shape

bike_data = bike_data.drop_duplicates()
bike_data.shape

#Result shows that there are no duplicates.
# Out:
# (730, 16)

# %%
#Exploratory Analysis

# %%
## 1. Remove Instant column an it doesnt make any sense as we already have that column
bike_data = bike_data.iloc[:,1:16]

# %%
bike_data.shape
# Out:
# (730, 15)

# %%
#removig dteday since we already have month and a year
bike_data = bike_data.iloc[:,1:16]

# %%
bike_data.shape
# Out:
# (730, 14)

# %%
bike_data = bike_data.drop("casual", axis=1)

# %%
bike_data = bike_data.drop("registered", axis=1)

# %%
bike_data.shape
# Out:
# (730, 12)

# %%
bike_data.info()

bike_data_new = bike_data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 730 entries, 0 to 729
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      730 non-null    int64
#  1   yr          730 non-null    int64
#  2   mnth        730 non-null    int64
#  3   holiday     730 non-null    int64
#  4   weekday     730 non-null    int64
#  5   workingday  730 non-null    int64
#  6   weathersit  730 non-null    int64
#  7   temp        730 non-null    float64
#  8   atemp       730 non-null    float64
#  9   hum         730 non-null    float64
#  10  windspeed   730 non-null    float64
#  11  cnt         730 non-null    int64
# dtypes: float64(4), int64(8)
# memory usage: 74.1 KB

# %%
#converting into categorical varible
bike_data_new["season"] = bike_data_new["season"].astype("category")

# %%
bike_data_new["weathersit"] = bike_data_new["weathersit"].astype("category")

# %%
bike_data_new["weekday"] = bike_data_new["weekday"].astype("category")

# %%
bike_data_new["mnth"] = bike_data_new["weekday"].astype("category")

# %%
bike_data_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 730 entries, 0 to 729
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      730 non-null    category
#  1   yr          730 non-null    int64
#  2   mnth        730 non-null    category
#  3   holiday     730 non-null    int64
#  4   weekday     730 non-null    category
#  5   workingday  730 non-null    int64
#  6   weathersit  730 non-null    category
#  7   temp        730 non-null    float64
#  8   atemp       730 non-null    float64
#  9   hum         730 non-null    float64
#  10  windspeed   730 non-null    float64
#  11  cnt         730 non-null    int64
# dtypes: category(4), float64(4), int64(4)
# memory usage: 55.2 KB

# %%
# create and drop dummy variables

bike_data_new = pd.get_dummies(bike_data_new, drop_first=True)
bike_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 730 entries, 0 to 729
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      730 non-null    category
#  1   yr          730 non-null    int64
#  2   mnth        730 non-null    category
#  3   holiday     730 non-null    int64
#  4   weekday     730 non-null    category
#  5   workingday  730 non-null    int64
#  6   weathersit  730 non-null    category
#  7   temp        730 non-null    float64
#  8   atemp       730 non-null    float64
#  9   hum         730 non-null    float64
#  10  windspeed   730 non-null    float64
#  11  cnt         730 non-null    int64
# dtypes: category(4), float64(4), int64(4)
# memory usage: 55.2 KB

# %%
bike_data_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 730 entries, 0 to 729
# Data columns (total 25 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   yr            730 non-null    int64
#  1   holiday       730 non-null    int64
#  2   workingday    730 non-null    int64
#  3   temp          730 non-null    float64
#  4   atemp         730 non-null    float64
#  5   hum           730 non-null    float64
#  6   windspeed     730 non-null    float64
#  7   cnt           730 non-null    int64
#  8   season_2      730 non-null    uint8
#  9   season_3      730 non-null    uint8
#  10  season_4      730 non-null    uint8
#  11  mnth_1        730 non-null    uint8
#  12  mnth_2        730 non-null    uint8
#  13  mnth_3        730 non-null    uint8
#  14  mnth_4        730 non-null    uint8
#  15  mnth_5        730 non-null    uint8
#  16  mnth_6        730 non-null    uint8
#  17  weekday_1     730 non-null    uint8
# ...

# %%
bike_data_new.shape
# Out:
# (730, 25)

# %%
# Split the data to train and test set

from sklearn.model_selection import train_test_split

# We specify this so that the train and test data set always have the same rows, respectively
np.random.seed(0)
df_train, df_test = train_test_split(bike_data_new, train_size = 0.7, test_size = 0.3, random_state = 100)

# %%
df_train.shape
# Out:
# (510, 25)

# %%
df_test.shape
# Out:
# (219, 25)

# %%
## Making Exploratory Analysis

df_train.columns
# Out:
# Index(['yr', 'holiday', 'workingday', 'temp', 'atemp', 'hum', 'windspeed',
#        'cnt', 'season_2', 'season_3', 'season_4', 'mnth_1', 'mnth_2', 'mnth_3',
#        'mnth_4', 'mnth_5', 'mnth_6', 'weekday_1', 'weekday_2', 'weekday_3',
#        'weekday_4', 'weekday_5', 'weekday_6', 'weathersit_2', 'weathersit_3'],
#       dtype='object')

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 510 entries, 653 to 79
# Data columns (total 25 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   yr            510 non-null    int64
#  1   holiday       510 non-null    int64
#  2   workingday    510 non-null    int64
#  3   temp          510 non-null    float64
#  4   atemp         510 non-null    float64
#  5   hum           510 non-null    float64
#  6   windspeed     510 non-null    float64
#  7   cnt           510 non-null    int64
#  8   season_2      510 non-null    uint8
#  9   season_3      510 non-null    uint8
#  10  season_4      510 non-null    uint8
#  11  mnth_1        510 non-null    uint8
#  12  mnth_2        510 non-null    uint8
#  13  mnth_3        510 non-null    uint8
#  14  mnth_4        510 non-null    uint8
#  15  mnth_5        510 non-null    uint8
#  16  mnth_6        510 non-null    uint8
#  17  weekday_1     510 non-null    uint8
# ...

# %%
#Analysing Numerical Variables.

bike_data_numeric_df = df_train[[ 'temp', 'atemp', 'hum', 'windspeed','cnt']]

# %%
bike_data_numeric_df.head()
# Out:
#           temp    atemp      hum  windspeed   cnt
# 653  19.201653  23.0423  55.8333  12.208807  7534
# 576  29.246653  33.1448  70.4167  11.083475  7216
# 426  16.980847  20.6746  62.1250  10.792293  4066
# 728  10.489153  11.5850  48.3333  23.500518  1796
# 482  15.443347  18.8752  48.9583   8.708325  4220

# %%
sns.pairplot(bike_data_numeric_df, diag_kind='kde')
plt.show()

# %%
#Above graph shows that there is a linear relationship between atemp, temp and cnt mainly.

# %%
##Analysing the Categorical Variable. Since its a categorical variable we will use boxplot instead of pairplot.

# %%
bike_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 730 entries, 0 to 729
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      730 non-null    category
#  1   yr          730 non-null    int64
#  2   mnth        730 non-null    category
#  3   holiday     730 non-null    int64
#  4   weekday     730 non-null    category
#  5   workingday  730 non-null    int64
#  6   weathersit  730 non-null    category
#  7   temp        730 non-null    float64
#  8   atemp       730 non-null    float64
#  9   hum         730 non-null    float64
#  10  windspeed   730 non-null    float64
#  11  casual      730 non-null    int64
#  12  registered  730 non-null    int64
#  13  cnt         730 non-null    int64
# dtypes: category(4), float64(4), int64(6)
# memory usage: 66.6 KB

# %%
plt.figure(figsize=(25, 10))
plt.subplot(2,3,1)
sns.boxplot(x = 'season', y = 'cnt', data = bike_data)
plt.subplot(2,3,2)
sns.boxplot(x = 'mnth', y = 'cnt', data = bike_data)
plt.subplot(2,3,3)
sns.boxplot(x = 'weathersit', y = 'cnt', data =bike_data)
plt.subplot(2,3,4)
sns.boxplot(x = 'holiday', y = 'cnt', data = bike_data)
plt.subplot(2,3,5)
sns.boxplot(x = 'weekday', y = 'cnt', data = bike_data)
plt.subplot(2,3,6)
sns.boxplot(x = 'workingday', y = 'cnt', data = bike_data)
plt.show()

# %%
plt.figure(figsize = (25,20))
sns.heatmap(bike_data.corr(), annot = True, cmap="RdBu")
plt.show()
# Out:
# /var/folders/p0/1rk_10953lsb1d3h6lm2_l3cr07298/T/ipykernel_40279/1820530021.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(bike_data.corr(), annot = True, cmap="RdBu")

# %%
##Performing Rescaling

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# %%
df_train.head()
# Out:
#      yr  holiday  workingday       temp    atemp      hum  windspeed   cnt  \
# 653   1        0           1  19.201653  23.0423  55.8333  12.208807  7534
# 576   1        0           1  29.246653  33.1448  70.4167  11.083475  7216
# 426   1        0           0  16.980847  20.6746  62.1250  10.792293  4066
# 728   1        0           0  10.489153  11.5850  48.3333  23.500518  1796
# 482   1        0           0  15.443347  18.8752  48.9583   8.708325  4220
#
#      season_2  season_3  ...  mnth_5  mnth_6  weekday_1  weekday_2  weekday_3  \
# 653         0         0  ...       0       0          0          1          0
# 576         0         1  ...       0       0          0          1          0
# 426         0         0  ...       0       1          0          0          0
# 728         0         0  ...       0       0          0          0          0
# 482         1         0  ...       0       1          0          0          0
#
# ...

# %%
num_vars = ['temp', 'atemp', 'hum', 'windspeed','cnt']

df_train[num_vars] = scaler.fit_transform(df_train[num_vars])

# %%
df_train.head()
# Out:
#      yr  holiday  workingday      temp     atemp       hum  windspeed  \
# 653   1        0           1  0.509887  0.501133  0.575354   0.300794
# 576   1        0           1  0.815169  0.766351  0.725633   0.264686
# 426   1        0           0  0.442393  0.438975  0.640189   0.255342
# 728   1        0           0  0.245101  0.200348  0.498067   0.663106
# 482   1        0           0  0.395666  0.391735  0.504508   0.188475
#
#           cnt  season_2  season_3  ...  mnth_5  mnth_6  weekday_1  weekday_2  \
# 653  0.864243         0         0  ...       0       0          0          1
# 576  0.827658         0         1  ...       0       0          0          1
# 426  0.465255         0         0  ...       0       1          0          0
# 728  0.204096         0         0  ...       0       0          0          0
# 482  0.482973         1         0  ...       0       1          0          0
#
#      weekday_3  weekday_4  weekday_5  weekday_6  weathersit_2  weathersit_3
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 510 entries, 653 to 79
# Data columns (total 25 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   yr            510 non-null    int64
#  1   holiday       510 non-null    int64
#  2   workingday    510 non-null    int64
#  3   temp          510 non-null    float64
#  4   atemp         510 non-null    float64
#  5   hum           510 non-null    float64
#  6   windspeed     510 non-null    float64
#  7   cnt           510 non-null    float64
#  8   season_2      510 non-null    uint8
#  9   season_3      510 non-null    uint8
#  10  season_4      510 non-null    uint8
#  11  mnth_1        510 non-null    uint8
#  12  mnth_2        510 non-null    uint8
#  13  mnth_3        510 non-null    uint8
#  14  mnth_4        510 non-null    uint8
#  15  mnth_5        510 non-null    uint8
#  16  mnth_6        510 non-null    uint8
#  17  weekday_1     510 non-null    uint8
# ...

# %%
#Buiding a Model

y_train = df_train.pop("cnt")
X_train = df_train

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()
lm.fit(X_train, y_train)

rfe = RFE(lm, n_features_to_select = 15)             # running RFE
rfe = rfe.fit(X_train, y_train)

# %%
list(zip(X_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('yr', False, 2),
#  ('holiday', True, 1),
#  ('workingday', True, 1),
#  ('temp', True, 1),
#  ('atemp', False, 10),
#  ('hum', False, 5),
#  ('windspeed', False, 4),
#  ('season_2', False, 7),
#  ('season_3', False, 8),
#  ('season_4', False, 6),
#  ('mnth_1', True, 1),
#  ('mnth_2', True, 1),
#  ('mnth_3', True, 1),
#  ('mnth_4', True, 1),
#  ('mnth_5', True, 1),
#  ('mnth_6', True, 1),
#  ('weekday_1', True, 1),
#  ('weekday_2', True, 1),
#  ('weekday_3', True, 1),
#  ('weekday_4', True, 1),
#  ('weekday_5', True, 1),
#  ('weekday_6', True, 1),
#  ('weathersit_2', False, 9),
#  ('weathersit_3', False, 3)]

# %%
col = X_train.columns[rfe.support_]
col
# Out:
# Index(['holiday', 'workingday', 'temp', 'mnth_1', 'mnth_2', 'mnth_3', 'mnth_4',
#        'mnth_5', 'mnth_6', 'weekday_1', 'weekday_2', 'weekday_3', 'weekday_4',
#        'weekday_5', 'weekday_6'],
#       dtype='object')

# %%
X_train.columns[~rfe.support_]
# Out:
# Index(['yr', 'atemp', 'hum', 'windspeed', 'season_2', 'season_3', 'season_4',
#        'weathersit_2', 'weathersit_3'],
#       dtype='object')

# %%
X_train_rfe = X_train[col]
X_train_rfe
# Out:
#      holiday  workingday      temp  mnth_1  mnth_2  mnth_3  mnth_4  mnth_5  \
# 653        0           1  0.509887       0       1       0       0       0
# 576        0           1  0.815169       0       1       0       0       0
# 426        0           0  0.442393       0       0       0       0       0
# 728        0           0  0.245101       0       0       0       0       0
# 482        0           0  0.395666       0       0       0       0       0
# ..       ...         ...       ...     ...     ...     ...     ...     ...
# 526        0           1  0.824514       1       0       0       0       0
# 578        0           1  0.863973       0       0       0       1       0
# 53         0           1  0.202618       0       0       1       0       0
# 350        0           0  0.248216       0       0       0       0       0
# 79         0           1  0.462664       1       0       0       0       0
#
# ...

# %%
import statsmodels.api as sm

from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

# %%
y_train.shape
# Out:
# (510,)

# %%
#Model without rfe

# %%
import statsmodels.api as sm

# Add a constant
X_train_lm = sm.add_constant(X_train)

# Create a first fitted model
lr = sm.OLS(y_train, X_train_lm).fit()

# %%
lr.params
# Out:
# const           0.167724
# yr              0.231777
# holiday        -0.039565
# workingday      0.044747
# temp            0.440046
# atemp           0.056062
# hum            -0.124995
# windspeed      -0.178022
# season_2        0.117136
# season_3        0.075460
# season_4        0.164331
# mnth_1         -0.004860
# mnth_2         -0.003261
# mnth_3          0.004796
# mnth_4          0.002110
# mnth_5          0.006399
# mnth_6          0.028294
# weekday_1      -0.004860
# weekday_2      -0.003261
# weekday_3       0.004796
# weekday_4       0.002110
# weekday_5       0.006399
# weekday_6       0.028294
# weathersit_2   -0.058571
# weathersit_3   -0.250681
# dtype: float64

# %%
print(lr.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.834
# Model:                            OLS   Adj. R-squared:                  0.828
# Method:                 Least Squares   F-statistic:                     145.5
# Date:                Wed, 11 Oct 2023   Prob (F-statistic):          2.06e-179
# Time:                        17:28:51   Log-Likelihood:                 496.63
# No. Observations:                 510   AIC:                            -957.3
# Df Residuals:                     492   BIC:                            -881.0
# Df Model:                          17
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.1677      0.030      5.601      0.000       0.109       0.227
# ...

# %%
##Checking for Variance inflation Factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# Create a dataframe that will contain the names of all the feature variables and their respective VIFs
vif = pd.DataFrame()
vif['Features'] = X_train.columns
vif['VIF'] = [variance_inflation_factor(X_train.values, i) for i in range(X_train.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
# /Users/z004ngl/anaconda3/lib/python3.11/site-packages/statsmodels/stats/outliers_influence.py:195: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
#         Features     VIF
# 12        mnth_3     inf
# 1        holiday     inf
# 20     weekday_5     inf
# 19     weekday_4     inf
# 18     weekday_3     inf
# 17     weekday_2     inf
# 16     weekday_1     inf
# 15        mnth_6     inf
# 14        mnth_5     inf
# 13        mnth_4     inf
# 11        mnth_2     inf
# 10        mnth_1     inf
# 2     workingday     inf
# 21     weekday_6     inf
# 3           temp  390.92
# 4          atemp  369.04
# 5            hum   17.56
# 8       season_3    6.59
# 6      windspeed    4.02
# 7       season_2    3.37
# 9       season_4    2.50
# 22  weathersit_2    2.15
# 0             yr    2.04
# 23  weathersit_3    1.19

# %%
##Model with Rfe

# %%
# vif = pd.DataFrame()
# vif['Features'] = X_train_rfe.columns
# vif['VIF'] = [variance_inflation_factor(X_train_rfe.values, i) for i in range(X_train_rfe.shape[1])]
# vif['VIF'] = round(vif['VIF'], 2)
# vif = vif.sort_values(by = "VIF", ascending = False)
# vif
# Out:
# /Users/z004ngl/anaconda3/lib/python3.11/site-packages/statsmodels/stats/outliers_influence.py:195: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
#       Features   VIF
# 0      holiday   inf
# 1   workingday   inf
# 3       mnth_1   inf
# 4       mnth_2   inf
# 5       mnth_3   inf
# 6       mnth_4   inf
# 7       mnth_5   inf
# 8       mnth_6   inf
# 9    weekday_1   inf
# 10   weekday_2   inf
# 11   weekday_3   inf
# 12   weekday_4   inf
# 13   weekday_5   inf
# 14   weekday_6   inf
# 2         temp  3.76

# %%
# X_train_lm1 = sm.add_constant(X_train_rfe)

# # Create a first fitted model
# lr1 = sm.OLS(y_train, X_train_lm1).fit()

# %%
# lr1.params
# Out:
# const         0.478823
# holiday      -0.088622
# workingday    0.058052
# mnth_1       -0.004644
# mnth_2       -0.002430
# mnth_3       -0.010235
# mnth_4       -0.006693
# mnth_6        0.013149
# weekday_1    -0.004644
# weekday_2    -0.002430
# weekday_4    -0.006693
# weekday_5    -0.006568
# weekday_6     0.013149
# dtype: float64

# %%
# print(lr1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.016
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     1.130
# Date:                Wed, 11 Oct 2023   Prob (F-statistic):              0.343
# Time:                        17:11:15   Log-Likelihood:                 42.497
# No. Observations:                 510   AIC:                            -68.99
# Df Residuals:                     502   BIC:                            -35.12
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4788      0.026     18.232      0.000       0.427       0.530
# ...

# %%
# Removing one with high Pvalue and vif
#Removing aTemp First
X_train_new = X_train_lm.drop(["atemp"], axis = 1)

# %%
# Create a dataframe that will contain the names of all the feature variables and their respective VIFs
vif = pd.DataFrame()
vif['Features'] = X_train_new.columns
vif['VIF'] = [variance_inflation_factor(X_train_new.values, i) for i in range(X_train_new.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
# /Users/z004ngl/anaconda3/lib/python3.11/site-packages/statsmodels/stats/outliers_influence.py:195: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
#         Features    VIF
# 12        mnth_3    inf
# 14        mnth_5    inf
# 2        holiday    inf
# 3     workingday    inf
# 21     weekday_6    inf
# 20     weekday_5    inf
# 19     weekday_4    inf
# 18     weekday_3    inf
# 17     weekday_2    inf
# 16     weekday_1    inf
# 10        mnth_1    inf
# 11        mnth_2    inf
# 15        mnth_6    inf
# 13        mnth_4    inf
# 0          const  52.65
# 8       season_3   4.79
# 4           temp   3.51
# 7       season_2   2.54
# 5            hum   1.89
# 9       season_4   1.87
# 22  weathersit_2   1.58
# 23  weathersit_3   1.26
# 6      windspeed   1.20
# 1             yr   1.04

# %%
X_train_lm2 = sm.add_constant(X_train_new)

# Create a first fitted model
lr2 = sm.OLS(y_train, X_train_lm2).fit()

# %%
lr2.params
# Out:
# const           0.168420
# yr              0.231707
# holiday        -0.040018
# workingday      0.044853
# temp            0.493259
# hum            -0.124334
# windspeed      -0.180095
# season_2        0.117211
# season_3        0.074489
# season_4        0.164608
# mnth_1         -0.004815
# mnth_2         -0.003295
# mnth_3          0.004700
# mnth_4          0.002123
# mnth_5          0.006122
# mnth_6          0.028279
# weekday_1      -0.004815
# weekday_2      -0.003295
# weekday_3       0.004700
# weekday_4       0.002123
# weekday_5       0.006122
# weekday_6       0.028279
# weathersit_2   -0.058655
# weathersit_3   -0.251429
# dtype: float64

# %%
print(lr2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.834
# Model:                            OLS   Adj. R-squared:                  0.829
# Method:                 Least Squares   F-statistic:                     154.9
# Date:                Wed, 11 Oct 2023   Prob (F-statistic):          1.76e-180
# Time:                        17:29:07   Log-Likelihood:                 496.55
# No. Observations:                 510   AIC:                            -959.1
# Df Residuals:                     493   BIC:                            -887.1
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.1684      0.030      5.639      0.000       0.110       0.227
# ...

# %%
#removing temp and registered as it has high vif value.

# X_train_new = X_train_new.drop(["registered"], axis = 1)
X_train_new = X_train_new.drop(["mnth_4"], axis = 1)

X_train_new = X_train_new.drop(["weekday_4"], axis = 1)

# %%
# Create a dataframe that will contain the names of all the feature variables and their respective VIFs
vif = pd.DataFrame()
vif['Features'] = X_train_new.columns
vif['VIF'] = [variance_inflation_factor(X_train_new.values, i) for i in range(X_train_new.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
# /Users/z004ngl/anaconda3/lib/python3.11/site-packages/statsmodels/stats/outliers_influence.py:195: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
#         Features    VIF
# 11        mnth_2    inf
# 10        mnth_1    inf
# 19     weekday_6    inf
# 18     weekday_5    inf
# 17     weekday_3    inf
# 16     weekday_2    inf
# 15     weekday_1    inf
# 14        mnth_6    inf
# 13        mnth_5    inf
# 12        mnth_3    inf
# 0          const  52.65
# 8       season_3   4.79
# 4           temp   3.51
# 3     workingday   3.21
# 7       season_2   2.54
# 5            hum   1.89
# 9       season_4   1.87
# 20  weathersit_2   1.58
# 2        holiday   1.40
# 21  weathersit_3   1.26
# 6      windspeed   1.20
# 1             yr   1.04

# %%
X_train_lm3 = sm.add_constant(X_train_new)

# Create a first fitted model
lr3 = sm.OLS(y_train, X_train_lm3).fit()

# %%
lr3.params
# Out:
# const           0.168420
# yr              0.231707
# holiday        -0.035772
# workingday      0.049099
# temp            0.493259
# hum            -0.124334
# windspeed      -0.180095
# season_2        0.117211
# season_3        0.074489
# season_4        0.164608
# mnth_1         -0.006938
# mnth_2         -0.005418
# mnth_3          0.002577
# mnth_5          0.004000
# mnth_6          0.028279
# weekday_1      -0.006938
# weekday_2      -0.005418
# weekday_3       0.002577
# weekday_5       0.004000
# weekday_6       0.028279
# weathersit_2   -0.058655
# weathersit_3   -0.251429
# dtype: float64

# %%
print(lr3.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.834
# Model:                            OLS   Adj. R-squared:                  0.829
# Method:                 Least Squares   F-statistic:                     154.9
# Date:                Wed, 11 Oct 2023   Prob (F-statistic):          1.76e-180
# Time:                        17:29:14   Log-Likelihood:                 496.55
# No. Observations:                 510   AIC:                            -959.1
# Df Residuals:                     493   BIC:                            -887.1
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.1684      0.030      5.639      0.000       0.110       0.227
# ...

# %%
#Removing mnt3 and weekday 3 during to higher pvalue and vif
X_train_new = X_train_new.drop(["mnth_3"], axis = 1)
X_train_new = X_train_new.drop(["weekday_3"], axis = 1)

# %%
# Create a dataframe that will contain the names of all the feature variables and their respective VIFs
vif = pd.DataFrame()
vif['Features'] = X_train_new.columns
vif['VIF'] = [variance_inflation_factor(X_train_new.values, i) for i in range(X_train_new.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
# /Users/z004ngl/anaconda3/lib/python3.11/site-packages/statsmodels/stats/outliers_influence.py:195: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
#         Features    VIF
# 10        mnth_1    inf
# 11        mnth_2    inf
# 17     weekday_6    inf
# 16     weekday_5    inf
# 15     weekday_2    inf
# 14     weekday_1    inf
# 13        mnth_6    inf
# 12        mnth_5    inf
# 0          const  52.60
# 8       season_3   4.79
# 4           temp   3.51
# 7       season_2   2.54
# 3     workingday   2.31
# 5            hum   1.89
# 9       season_4   1.87
# 18  weathersit_2   1.58
# 2        holiday   1.33
# 19  weathersit_3   1.26
# 6      windspeed   1.20
# 1             yr   1.04

# %%
X_train_lm4 = sm.add_constant(X_train_new)

# Create a first fitted model
lr4 = sm.OLS(y_train, X_train_lm4).fit()

# %%
lr4.params
# Out:
# const           0.168101
# yr              0.231717
# holiday        -0.033410
# workingday      0.051895
# temp            0.493574
# hum            -0.123995
# windspeed      -0.180150
# season_2        0.117206
# season_3        0.074269
# season_4        0.164516
# mnth_1         -0.008311
# mnth_2         -0.006820
# mnth_5          0.002604
# mnth_6          0.028280
# weekday_1      -0.008311
# weekday_2      -0.006820
# weekday_5       0.002604
# weekday_6       0.028280
# weathersit_2   -0.058592
# weathersit_3   -0.251223
# dtype: float64

# %%
print(lr4.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.834
# Model:                            OLS   Adj. R-squared:                  0.829
# Method:                 Least Squares   F-statistic:                     165.5
# Date:                Wed, 11 Oct 2023   Prob (F-statistic):          1.42e-181
# Time:                        17:29:20   Log-Likelihood:                 496.49
# No. Observations:                 510   AIC:                            -961.0
# Df Residuals:                     494   BIC:                            -893.2
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.1681      0.030      5.636      0.000       0.110       0.227
# ...

# %%
#Removing weekday 2 due to higher pvalue and vif
#Removing mnt3 and weekday 3 during to higher pvalue and vif
X_train_new = X_train_new.drop(["mnth_5"], axis = 1)
X_train_new = X_train_new.drop(["weekday_5"], axis = 1)

# %%
# Create a dataframe that will contain the names of all the feature variables and their respective VIFs
vif = pd.DataFrame()
vif['Features'] = X_train_new.columns
vif['VIF'] = [variance_inflation_factor(X_train_new.values, i) for i in range(X_train_new.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
# /Users/z004ngl/anaconda3/lib/python3.11/site-packages/statsmodels/stats/outliers_influence.py:195: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
#         Features    VIF
# 12        mnth_6    inf
# 15     weekday_6    inf
# 14     weekday_2    inf
# 13     weekday_1    inf
# 10        mnth_1    inf
# 11        mnth_2    inf
# 0          const  52.56
# 8       season_3   4.79
# 4           temp   3.51
# 7       season_2   2.54
# 3     workingday   2.08
# 5            hum   1.88
# 9       season_4   1.87
# 16  weathersit_2   1.57
# 2        holiday   1.30
# 17  weathersit_3   1.25
# 6      windspeed   1.20
# 1             yr   1.04

# %%
X_train_lm5 = sm.add_constant(X_train_new)

# Create a first fitted model
lr5 = sm.OLS(y_train, X_train_lm5).fit()

# %%
lr5.params
# Out:
# const           0.168386
# yr              0.231672
# holiday        -0.031804
# workingday      0.053462
# temp            0.493608
# hum            -0.124535
# windspeed      -0.180165
# season_2        0.117135
# season_3        0.074335
# season_4        0.164499
# mnth_1         -0.009100
# mnth_2         -0.007614
# mnth_6          0.028271
# weekday_1      -0.009100
# weekday_2      -0.007614
# weekday_6       0.028271
# weathersit_2   -0.058264
# weathersit_3   -0.251864
# dtype: float64

# %%
print(lr5.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.834
# Model:                            OLS   Adj. R-squared:                  0.829
# Method:                 Least Squares   F-statistic:                     177.6
# Date:                Wed, 11 Oct 2023   Prob (F-statistic):          1.12e-182
# Time:                        17:29:23   Log-Likelihood:                 496.42
# No. Observations:                 510   AIC:                            -962.8
# Df Residuals:                     495   BIC:                            -899.3
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.1684      0.030      5.653      0.000       0.110       0.227
# ...

# %%
X_train_new = X_train_new.drop(["mnth_6"], axis = 1)
X_train_new = X_train_new.drop(["weekday_6"], axis = 1)
X_train_new = X_train_new.drop(["mnth_1"], axis = 1)
X_train_new = X_train_new.drop(["weekday_1"], axis = 1)
X_train_new = X_train_new.drop(["mnth_2"], axis = 1)
X_train_new = X_train_new.drop(["weekday_2"], axis = 1)

# %%
# Create a dataframe that will contain the names of all the feature variables and their respective VIFs
vif = pd.DataFrame()
vif['Features'] = X_train_new.columns
vif['VIF'] = [variance_inflation_factor(X_train_new.values, i) for i in range(X_train_new.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#         Features    VIF
# 0          const  47.22
# 8       season_3   4.78
# 4           temp   3.50
# 7       season_2   2.54
# 5            hum   1.87
# 9       season_4   1.87
# 10  weathersit_2   1.56
# 11  weathersit_3   1.24
# 6      windspeed   1.20
# 2        holiday   1.07
# 3     workingday   1.07
# 1             yr   1.03

# %%
X_train_lm6 = sm.add_constant(X_train_new)

# Create a first fitted model
lr6 = sm.OLS(y_train, X_train_lm6).fit()

# %%
lr6.params
# Out:
# const           0.205706
# yr              0.230287
# holiday        -0.074835
# workingday      0.017496
# temp            0.494988
# hum            -0.138240
# windspeed      -0.180687
# season_2        0.116349
# season_3        0.074400
# season_4        0.163586
# weathersit_2   -0.054501
# weathersit_3   -0.242643
# dtype: float64

# %%
print(lr6.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.828
# Model:                            OLS   Adj. R-squared:                  0.825
# Method:                 Least Squares   F-statistic:                     218.6
# Date:                Wed, 11 Oct 2023   Prob (F-statistic):          1.26e-182
# Time:                        17:29:28   Log-Likelihood:                 488.00
# No. Observations:                 510   AIC:                            -952.0
# Df Residuals:                     498   BIC:                            -901.2
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.2057      0.029      7.188      0.000       0.149       0.262
# ...

# %%
X_train_new = X_train_new.drop(["const"], axis = 1)

# %%
# Create a dataframe that will contain the names of all the feature variables and their respective VIFs
vif = pd.DataFrame()
vif['Features'] = X_train_new.columns
vif['VIF'] = [variance_inflation_factor(X_train_new.values, i) for i in range(X_train_new.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#         Features    VIF
# 3           temp  22.74
# 4            hum  16.08
# 7       season_3   6.48
# 5      windspeed   3.67
# 6       season_2   3.36
# 2     workingday   3.13
# 8       season_4   2.49
# 9   weathersit_2   2.13
# 0             yr   2.03
# 10  weathersit_3   1.17
# 1        holiday   1.09

# %%
X_train_lm7 = sm.add_constant(X_train_new)

# Create a first fitted model
lr7 = sm.OLS(y_train, X_train_lm7).fit()

# %%
print(lr7.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.828
# Model:                            OLS   Adj. R-squared:                  0.825
# Method:                 Least Squares   F-statistic:                     218.6
# Date:                Wed, 11 Oct 2023   Prob (F-statistic):          1.26e-182
# Time:                        17:29:36   Log-Likelihood:                 488.00
# No. Observations:                 510   AIC:                            -952.0
# Df Residuals:                     498   BIC:                            -901.2
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.2057      0.029      7.188      0.000       0.149       0.262
# ...

# %%
X_train_new = X_train_new.drop(["hum"], axis = 1)

# %%
# Create a dataframe that will contain the names of all the feature variables and their respective VIFs
vif = pd.DataFrame()
vif['Features'] = X_train_new.columns
vif['VIF'] = [variance_inflation_factor(X_train_new.values, i) for i in range(X_train_new.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#        Features    VIF
# 3          temp  15.14
# 6      season_3   6.17
# 4     windspeed   3.39
# 5      season_2   3.32
# 2    workingday   2.93
# 7      season_4   2.39
# 0            yr   2.03
# 8  weathersit_2   1.49
# 9  weathersit_3   1.08
# 1       holiday   1.07

# %%
X_train_lm8 = sm.add_constant(X_train_new)

# Create a first fitted model
lr8 = sm.OLS(y_train, X_train_lm8).fit()

# %%
print(lr8.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.824
# Model:                            OLS   Adj. R-squared:                  0.821
# Method:                 Least Squares   F-statistic:                     233.8
# Date:                Wed, 11 Oct 2023   Prob (F-statistic):          3.79e-181
# Time:                        17:29:49   Log-Likelihood:                 481.67
# No. Observations:                 510   AIC:                            -941.3
# Df Residuals:                     499   BIC:                            -894.8
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.1280      0.019      6.896      0.000       0.092       0.164
# ...

# %%
X_train_new = X_train_new.drop(["season_3"], axis = 1)

# %%
# Create a dataframe that will contain the names of all the feature variables and their respective VIFs
vif = pd.DataFrame()
vif['Features'] = X_train_new.columns
vif['VIF'] = [variance_inflation_factor(X_train_new.values, i) for i in range(X_train_new.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#        Features   VIF
# 3          temp  3.96
# 4     windspeed  3.18
# 2    workingday  2.92
# 0            yr  2.01
# 5      season_2  1.50
# 7  weathersit_2  1.49
# 6      season_4  1.39
# 8  weathersit_3  1.08
# 1       holiday  1.07

# %%
X_train_lm9 = sm.add_constant(X_train_new)

# Create a first fitted model
lr9 = sm.OLS(y_train, X_train_lm9).fit()

# %%
print(lr9.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.819
# Model:                            OLS   Adj. R-squared:                  0.815
# Method:                 Least Squares   F-statistic:                     250.8
# Date:                Wed, 11 Oct 2023   Prob (F-statistic):          4.79e-179
# Time:                        17:31:58   Log-Likelihood:                 473.85
# No. Observations:                 510   AIC:                            -927.7
# Df Residuals:                     500   BIC:                            -885.4
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.1136      0.018      6.154      0.000       0.077       0.150
# ...

# %%
lr9.params
# Out:
# const           0.113627
# yr              0.231558
# holiday        -0.077744
# workingday      0.018088
# temp            0.573845
# windspeed      -0.161943
# season_2        0.073553
# season_4        0.128051
# weathersit_2   -0.075772
# weathersit_3   -0.276427
# dtype: float64

# %%
y_train_pred = lr9.predict(X_train_lm9)

# %%
res = y_train-y_train_pred
# Plot the histogram of the error terms
fig = plt.figure()
sns.distplot((res), bins = 20)
fig.suptitle('Error Terms', fontsize = 20)                  # Plot heading 
plt.xlabel('Errors', fontsize = 18)
# Out:
# /var/folders/p0/1rk_10953lsb1d3h6lm2_l3cr07298/T/ipykernel_16760/1755506241.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot((res), bins = 20)
# Text(0.5, 0, 'Errors')

# %%
num_vars = ['temp', 'atemp', 'hum', 'windspeed','cnt']

df_test[num_vars] = scaler.transform(df_test[num_vars])

# %%
y_test = df_test.pop('cnt')
X_test = df_test
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 219 entries, 184 to 72
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   yr            219 non-null    int64
#  1   holiday       219 non-null    int64
#  2   workingday    219 non-null    int64
#  3   temp          219 non-null    float64
#  4   atemp         219 non-null    float64
#  5   hum           219 non-null    float64
#  6   windspeed     219 non-null    float64
#  7   season_2      219 non-null    uint8
#  8   season_3      219 non-null    uint8
#  9   season_4      219 non-null    uint8
#  10  mnth_1        219 non-null    uint8
#  11  mnth_2        219 non-null    uint8
#  12  mnth_3        219 non-null    uint8
#  13  mnth_4        219 non-null    uint8
#  14  mnth_5        219 non-null    uint8
#  15  mnth_6        219 non-null    uint8
#  16  weekday_1     219 non-null    uint8
#  17  weekday_2     219 non-null    uint8
# ...

# %%
col1=X_train_new.columns
X_test=X_test[col1]
# Adding constant variable to test dataframe
X_test_lm9 = sm.add_constant(X_test)
X_test_lm9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 219 entries, 184 to 72
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   const         219 non-null    float64
#  1   yr            219 non-null    int64
#  2   holiday       219 non-null    int64
#  3   workingday    219 non-null    int64
#  4   temp          219 non-null    float64
#  5   windspeed     219 non-null    float64
#  6   season_2      219 non-null    uint8
#  7   season_4      219 non-null    uint8
#  8   weathersit_2  219 non-null    uint8
#  9   weathersit_3  219 non-null    uint8
# dtypes: float64(3), int64(3), uint8(4)
# memory usage: 12.8 KB

# %%
y_pred = lr9.predict(X_test_lm9)

# %%
fig = plt.figure()
plt.scatter(y_test, y_pred, alpha=.5)
fig.suptitle('y_test vs y_pred', fontsize = 20)              # Plot heading 
plt.xlabel('y_test', fontsize = 18)                          # X-label
plt.ylabel('y_pred', fontsize = 16) 
plt.show()

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.7856398428833878

# %%
n = X_test.shape[0]


# Number of features (predictors, p) is the shape along axis 1
p = X_test.shape[1]

# We find the Adjusted R-squared using the formula

adjusted_r2 = 1-(1-0.7856398428833878)*(n-1)/(n-p-1)
adjusted_r2
# Out:
# 0.7764090227204715
